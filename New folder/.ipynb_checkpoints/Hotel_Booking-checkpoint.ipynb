# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../datasets/kaggle/hotel_bookings.csv')

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
ham = ['lead_time', 'is_repeated_guest', 'previous_cancellations', 'deposit_type', 'days_in_waiting_list','customer_type', 'adr', 'reservation_status']

# %%
new_data = data.get(ham)

# %%
new_data.head()
# Out:
#    lead_time  is_repeated_guest  previous_cancellations deposit_type  \
# 0        342                  0                       0   No Deposit
# 1        737                  0                       0   No Deposit
# 2          7                  0                       0   No Deposit
# 3         13                  0                       0   No Deposit
# 4         14                  0                       0   No Deposit
#
#    days_in_waiting_list customer_type   adr reservation_status
# 0                     0     Transient   0.0          Check-Out
# 1                     0     Transient   0.0          Check-Out
# 2                     0     Transient  75.0          Check-Out
# 3                     0     Transient  75.0          Check-Out
# 4                     0     Transient  98.0          Check-Out

# %%
new_data.shape
# Out:
# (119390, 8)

# %%
new_data.describe(include='all')
# Out:
#             lead_time  is_repeated_guest  previous_cancellations deposit_type  \
# count   119390.000000      119390.000000           119390.000000       119390
# unique            NaN                NaN                     NaN            3
# top               NaN                NaN                     NaN   No Deposit
# freq              NaN                NaN                     NaN       104641
# mean       104.011416           0.031912                0.087118          NaN
# std        106.863097           0.175767                0.844336          NaN
# min          0.000000           0.000000                0.000000          NaN
# 25%         18.000000           0.000000                0.000000          NaN
# 50%         69.000000           0.000000                0.000000          NaN
# 75%        160.000000           0.000000                0.000000          NaN
# max        737.000000           1.000000               26.000000          NaN
#
# ...

# %%
np.unique(new_data['deposit_type'], return_counts=True)
# Out:
# (array(['No Deposit', 'Non Refund', 'Refundable'], dtype=object),
#  array([104641,  14587,    162], dtype=int64))

# %%
cut = new_data.get('deposit_type')

# %%
cut.count(np.)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-089195fe3fa0> in <module>
# ----> 1 cut.count('nan')
#
# D:\anaconda3\lib\site-packages\pandas\core\series.py in count(self, level)
#    1718
#    1719         if isinstance(level, str):
# -> 1720             level = self.index._get_level_number(level)
#    1721
#    1722         lev = self.index.levels[level]
#
# D:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_level_number(self, level)
#    1418
#    1419     def _get_level_number(self, level):
# -> 1420         self._validate_index_level(level)
#    1421         return 0
#    1422
#
# D:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _validate_index_level(self, level)
#    1414         elif level != self.name:
#    1415             raise KeyError(
# ...

# %%
X, y = data.drop(['is_canceled'], axis=1), data['is_canceled']

# %%
X.shape
# Out:
# (119390, 31)

# %%
y.shape
# Out:
# (119390,)
