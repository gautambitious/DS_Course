# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageOps

# %%
image = img.open("invite.png")
image = np.array(image)

# %%
image.shape
# Out:
# (1120, 800, 3)

# %%
def show(arr):
    plt.imshow(arr)

# %%
show(image)

# %%
cut = image[890:,:image.shape[1]//2]
cut2 = image[890:,image.shape[1]//2:]

# %%
cutim = Image.fromarray(cut)
cutim2 = ImageOps.mirror(cutim)

# %%
cut2 = np.array(cutim2)

# %%
image[890:,image.shape[1]//2:] = cut2

# %%
show(np.hstack([cut, cut2]))

# %%
show(image)

# %%
with open("final.png", "wb") as f:
    target = img.fromarray(image)
    target.save(f)
